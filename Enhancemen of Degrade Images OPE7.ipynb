# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
input_folder = r"c:\Users\shash\OneDrive\Desktop\SEMESTER05\DSIP(01CT0513)\IMAGES\LAB IMAGES"
output_folder = r"c:\Users\shash\OneDrive\Desktop\SEMESTER05\DSIP(01CT0513)\IMAGES\LAB IMAGES ENHANCED"
os.makedirs(output_folder, exist_ok=True)
print("Folders ready")
# Out:
# Folders ready

# %%
image1 = cv2.imread(os.path.join(input_folder, "01.png"))
image2 = cv2.imread(os.path.join(input_folder, "02.png"))
image3 = cv2.imread(os.path.join(input_folder, "03.png"))
image4 = cv2.imread(os.path.join(input_folder, "04.png"))
image5 = cv2.imread(os.path.join(input_folder, "05.png"))

images = [image1, image2, image3, image4, image5]

for i, img in enumerate(images, 1):
    if img is None:
        print("Image", i, "not found")
    else:
        print("Image", i, "loaded successfully")
# Out:
# Image 1 loaded successfully
# Image 2 loaded successfully
# Image 3 loaded successfully
# Image 4 loaded successfully
# Image 5 loaded successfully

# %%
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)
gray4 = cv2.cvtColor(image4, cv2.COLOR_BGR2GRAY)
gray5 = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)

gray_images = [gray1, gray2, gray3, gray4, gray5]

print("All images converted to grayscale")
# Out:
# All images converted to grayscale

# %%
plt.figure(figsize=(15, 8))

for i, img in enumerate(gray_images, 1):
    plt.subplot(2, 3, i)
    plt.imshow(img, cmap="gray")
    plt.title("Image " + str(i))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.imshow(gray1, cmap="gray")
plt.title("Image 1 - Original")
plt.axis("off")
plt.show()

# %%
r_min = np.min(gray1)
r_max = np.max(gray1)

contrast1 = ((gray1 - r_min) / (r_max - r_min) * 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image1_contrast_stretching.png"),
    contrast1
)

plt.figure(figsize=(6, 5))
plt.imshow(contrast1, cmap="gray")
plt.title("Image 1 - Contrast Stretching")
plt.axis("off")
plt.show()

# %%
gamma = 0.6

gamma1 = 255 * (gray1.astype(np.float32) / 255) ** gamma
gamma1 = np.clip(gamma1, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image1_gamma.png"),
    gamma1
)

plt.figure(figsize=(6, 5))
plt.imshow(gamma1, cmap="gray")
plt.title("Image 1 - Gamma Transformation")
plt.axis("off")
plt.show()

# %%
c = 255 / np.log(1 + np.max(gray1))

log1 = c * np.log(1 + gray1.astype(np.float32))
log1 = np.clip(log1, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image1_log.png"),
    log1
)

plt.figure(figsize=(6, 5))
plt.imshow(log1, cmap="gray")
plt.title("Image 1 - Log Transformation")
plt.axis("off")
plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\3680458346.py:1: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(gray1))
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\3680458346.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(gray1))

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray1, cmap="gray")
plt.title("Original Image 1")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast1, cmap="gray")
plt.title("Contrast Stretching")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(gamma1, cmap="gray")
plt.title("Gamma Transformation")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(log1, cmap="gray")
plt.title("Log Transformation")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.imshow(gray2, cmap="gray")
plt.title("Image 2 - Original")
plt.axis("off")
plt.show()

# %%
c = 255 / np.log(1 + np.max(gray2))

log2 = c * np.log(1 + gray2.astype(np.float32))
log2 = np.clip(log2, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image2_log.png"),
    log2
)

plt.figure(figsize=(6, 5))
plt.imshow(log2, cmap="gray")
plt.title("Image 2 - Log Transformation")
plt.axis("off")
plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\2297028482.py:1: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(gray2))
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\2297028482.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(gray2))

# %%
    gamma = 0.7

    gamma2 = 255 * (gray2.astype(np.float32) / 255) ** gamma
    gamma2 = np.clip(gamma2, 0, 255).astype(np.uint8)

    cv2.imwrite(
        os.path.join(output_folder, "image2_gamma.png"),
        gamma2
    )

    plt.figure(figsize=(6, 5))
    plt.imshow(gamma2, cmap="gray")
    plt.title("Image 2 - Gamma Transformation")
    plt.axis("off")
    plt.show()

# %%
r_min = np.min(gray2)
r_max = np.max(gray2)

contrast2 = ((gray2 - r_min) / (r_max - r_min) * 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image2_contrast.png"),
    contrast2
)

plt.figure(figsize=(6, 5))
plt.imshow(contrast2, cmap="gray")
plt.title("Image 2 - Contrast Stretching")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray2, cmap="gray")
plt.title("Original Image 2")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast2, cmap="gray")
plt.title("Contrast Stretching")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(gamma2, cmap="gray")
plt.title("Gamma Transformation")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(log2, cmap="gray")
plt.title("Log Transformation")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.imshow(gray3, cmap="gray")
plt.title("Image 3 - Original")
plt.axis("off")
plt.show()

# %%
gamma = 0.4

gamma3 = 255 * (gray3.astype(np.float32) / 255) ** gamma
gamma3 = np.clip(gamma3, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image3_gamma.png"),
    gamma3
)

plt.figure(figsize=(6, 5))
plt.imshow(gamma3, cmap="gray")
plt.title("Image 3 - Gamma Transformation")
plt.axis("off")
plt.show()

# %%
c = 255 / np.log(1 + np.max(gray3))

log3 = c * np.log(1 + gray3.astype(np.float32))
log3 = np.clip(log3, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image3_log.png"),
    log3
)

plt.figure(figsize=(6, 5))
plt.imshow(log3, cmap="gray")
plt.title("Image 3 - Log Transformation")
plt.axis("off")
plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\1884709926.py:1: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(gray3))
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\1884709926.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(gray3))

# %%
r_min = np.min(gray3)
r_max = np.max(gray3)

contrast3 = ((gray3 - r_min) / (r_max - r_min) * 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image3_contrast.png"),
    contrast3
)

plt.figure(figsize=(6, 5))
plt.imshow(contrast3, cmap="gray")
plt.title("Image 3 - Contrast Stretching")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray3, cmap="gray")
plt.title("Original Image 3")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast3, cmap="gray")
plt.title("Contrast Stretching")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(gamma3, cmap="gray")
plt.title("Gamma Transformation")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(log3, cmap="gray")
plt.title("Log Transformation")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.imshow(gray4, cmap="gray")
plt.title("Image 4 - Original")
plt.axis("off")
plt.show()

# %%
c = 255 / np.log(1 + np.max(gray4))

log4 = c * np.log(1 + gray4.astype(np.float32))
log4 = np.clip(log4, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image4_log.png"),
    log4
)

plt.figure(figsize=(6, 5))
plt.imshow(log4, cmap="gray")
plt.title("Image 4 - Log Transformation")
plt.axis("off")
plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\2208196245.py:1: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(gray4))
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\2208196245.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(gray4))

# %%
gamma = 0.3

gamma4 = 255 * (gray4.astype(np.float32) / 255) ** gamma
gamma4 = np.clip(gamma4, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image4_gamma.png"),
    gamma4
)

plt.figure(figsize=(6, 5))
plt.imshow(gamma4, cmap="gray")
plt.title("Image 4 - Gamma Transformation")
plt.axis("off")
plt.show()

# %%
r_min = np.min(gray4)
r_max = np.max(gray4)

contrast4 = ((gray4 - r_min) / (r_max - r_min) * 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image4_contrast.png"),
    contrast4
)

plt.figure(figsize=(6, 5))
plt.imshow(contrast4, cmap="gray")
plt.title("Image 4 - Contrast Stretching")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray4, cmap="gray")
plt.title("Original Image 4")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast4, cmap="gray")
plt.title("Contrast Stretching")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(gamma4, cmap="gray")
plt.title("Gamma Transformation")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(log4, cmap="gray")
plt.title("Log Transformation")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.imshow(gray5, cmap="gray")
plt.title("Image 5 - Original")
plt.axis("off")
plt.show()

# %%
gamma = 0.4

gamma5 = 255 * (gray5.astype(np.float32) / 255) ** gamma
gamma5 = np.clip(gamma5, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image5_gamma.png"),
    gamma5
)

plt.figure(figsize=(6, 5))
plt.imshow(gamma5, cmap="gray")
plt.title("Image 5 - Gamma Transformation")
plt.axis("off")
plt.show()

# %%
c = 255 / np.log(1 + np.max(gray5))

log5 = c * np.log(1 + gray5.astype(np.float32))
log5 = np.clip(log5, 0, 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image5_log.png"),
    log5
)

plt.figure(figsize=(6, 5))
plt.imshow(log5, cmap="gray")
plt.title("Image 5 - Log Transformation")
plt.axis("off")
plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\3529787003.py:1: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(gray5))
# C:\Users\shash\AppData\Local\Temp\ipykernel_21948\3529787003.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(gray5))

# %%
r_min = np.min(gray5)
r_max = np.max(gray5)

contrast5 = ((gray5 - r_min) / (r_max - r_min) * 255).astype(np.uint8)

cv2.imwrite(
    os.path.join(output_folder, "image5_contrast.png"),
    contrast5
)

plt.figure(figsize=(6, 5))
plt.imshow(contrast5, cmap="gray")
plt.title("Image 5 - Contrast Stretching")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray5, cmap="gray")
plt.title("Original Image 5")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.imshow(contrast5, cmap="gray")
plt.title("Contrast Stretching")
plt.axis("off")

plt.subplot(2, 2, 3)
plt.imshow(gamma5, cmap="gray")
plt.title("Gamma Transformation")
plt.axis("off")

plt.subplot(2, 2, 4)
plt.imshow(log5, cmap="gray")
plt.title("Log Transformation")
plt.axis("off")

plt.tight_layout()
plt.show()
